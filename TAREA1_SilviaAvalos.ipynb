# %% [markdown]
# ### Explorar el dataset:
# ### - Desplegar nombres de columnas
# ### - Tipo de datos
# ### - Distribucion de NaNs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('dataset.csv')

# %%
print('Lo nombres de las columnas y su tipo de datos son: ')

#Utilizamos .colums.values para obtener los nombres de las columnas (se devuelven en un arreglo)
nombrecol = df.columns.values

#Utilizamos .dtypes para obtener el tipo de datos que existen en el DataFrame
df.dtypes
# Out:
# Lo nombres de las columnas y su tipo de datos son:
# Country                object
# ISO 3166-1 alpha-3     object
# Year                    int64
# Total                 float64
# Coal                  float64
# Oil                   float64
# Gas                   float64
# Cement                float64
# Flaring               float64
# Other                 float64
# Per Capita            float64
# dtype: object

# %%
#Distribución de NaNs
df.loc['Afghanistan':'Global','ISO 3166-1 alpha-3':'Per Capita'] = np.nan
df
# Out:
#            Country ISO 3166-1 alpha-3    Year         Total          Coal  \
# 0      Afghanistan                AFG  1750.0      0.000000           NaN
# 1      Afghanistan                AFG  1751.0      0.000000           NaN
# 2      Afghanistan                AFG  1752.0      0.000000           NaN
# 3      Afghanistan                AFG  1753.0      0.000000           NaN
# 4      Afghanistan                AFG  1754.0      0.000000           NaN
# ...            ...                ...     ...           ...           ...
# 63099       Global                WLD  2017.0  36096.739276  14506.973805
# 63100       Global                WLD  2018.0  36826.506600  14746.830688
# 63101       Global                WLD  2019.0  37082.558969  14725.978025
# 63102       Global                WLD  2020.0  35264.085734  14174.564010
# 63103       Global                WLD  2021.0  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# ...

# %% [markdown]
# ### ¿De cuántos países diferentes hay datos?

# %%
#Utilizamos .unique, esto nos devuleve los elementos únicos de un arreglo
dif_paises = len(df['Country'].unique())
#Imprimimos el resultato
print(f"Existen datos de {dif_paises} países diferentes.")
# Out:
# Existen datos de 232 países diferentes.

# %% [markdown]
# ### Graficar los valores globales y los de México para: 'Total', 'Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Per Capita'.

# %%
#Del conjunto de datos completo, obtenemos todos los valores globales y los de México
globald = df[(df['Country'] == 'Global')]
#globald
mexicod = df[(df['Country'] == 'Mexico')]
#mexicod

#Hacemos una lista con los valores que se nos pide graficar
valoresgraf = ['Total', 'Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Per Capita']

#Con un ciclo for recorremos y graficamos los datos de la lista hecha anteriormente, se grafican los datos globales vs los de México
for valoresgraf in valoresgraf:
    plt.title(valoresgraf)
    plt.xlabel('Año')
    plt.ylabel('MtCO2')
    plt.plot(globald['Year'], globald[valoresgraf], label='Global')
    plt.plot(mexicod['Year'], mexicod[valoresgraf], label='México')
    plt.legend()
    plt.show()

# %% [markdown]
# ### Extraer datos de los países pertenecientes al G20 y graficar las columnas del punto anterior.
# ### - ¿Cuáles son los 3 países que más contaminan en cada uno de los casos?
# ### - Considerando solo la emisión de los paises del G20, ¿Con qué porcentaje contribuye México al Total y Per Capita?

# %%
#Del conjunto de datos completo, obtenemos todos los valores globales y los de México
arg = df[(df['Country'] == 'Argentina')]
aust = df[(df['Country'] == 'Australia')]
bra = df[(df['Country'] == 'Brazil')]
can = df[(df['Country'] == 'Canada')]
chin = df[(df['Country'] == 'China')]
fran = df[(df['Country'] == 'France')]
indi = df[(df['Country'] == 'India')]
indo = df[(df['Country'] == 'Indonesia')]
ita = df[(df['Country'] == 'Italy')]
jap = df[(df['Country'] == 'Japan')]
mex = df[(df['Country'] == 'Mexico')]
kor = df[(df['Country'] == 'South Korea')]
rus = df[(df['Country'] == 'Russia')]
safr = df[(df['Country'] == 'South Africa')]
tur = df[(df['Country'] == 'Turkey')]
ukin = df[(df['Country'] == 'United Kingdom')]
usa = df[(df['Country'] == 'USA')]
sarab = df[(df['Country'] == 'Saudi Arabia SAU')]
germ = df[(df['Country'] == 'Germany')]

#Usamos la lista de valores creada en el punto anterior "valoresgraf"
valoresgraf = ['Total', 'Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Per Capita']
#Con un ciclo for recorremos y graficamos los datos de la lista hecha anteriormente, se grafican los datos de la G20
for valoresgraf in valoresgraf:
    plt.title(valoresgraf)
    plt.xlabel('Año')
    plt.ylabel('MtCO2')
    plt.plot(arg['Year'], arg[valoresgraf], label='Argentina')
    plt.plot(aust['Year'], aust[valoresgraf], label='Australia')
    plt.plot(bra['Year'], bra[valoresgraf], label='Brasil')
    plt.plot(can['Year'], can[valoresgraf], label='Canadá')
    plt.plot(chin['Year'], chin[valoresgraf], label='China')
    plt.plot(fran['Year'], fran[valoresgraf], label='Francia')
    plt.plot(indi['Year'], indi[valoresgraf], label='India')
    plt.plot(indo['Year'], indo[valoresgraf], label='Indonesia')
    plt.plot(ita['Year'], ita[valoresgraf], label='Italia')
    plt.plot(jap['Year'], jap[valoresgraf], label='Japon')
    plt.legend()
    plt.show()

# %%
#Usamos la lista de valores creada en el punto anterior "valoresgraf"
valoresgraf = ['Total', 'Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Per Capita']
#Con un ciclo for recorremos y graficamos los datos de la lista hecha anteriormente, se grafican los datos de la G20
for valoresgraf in valoresgraf:
    plt.title(valoresgraf)
    plt.xlabel('Año')
    plt.ylabel('MtCO2')
    plt.plot(mex['Year'], mex[valoresgraf], label='México')
    plt.plot(kor['Year'], kor[valoresgraf], label='Sur Corea')
    plt.plot(rus['Year'], rus[valoresgraf], label='Rusia')
    plt.plot(safr['Year'], safr[valoresgraf], label='Sudáfrica')
    plt.plot(tur['Year'], tur[valoresgraf], label='Turquía')
    plt.plot(ukin['Year'], ukin[valoresgraf], label='Reino Unido')
    plt.plot(usa['Year'], usa[valoresgraf], label='USA')
    plt.plot(sarab['Year'], sarab[valoresgraf], label='Arabia Saudita')
    plt.plot(germ['Year'], germ[valoresgraf], label='Alemania')
    plt.legend()
    plt.show()

# %%
#Para contestar las siguientes preguntas, creamos un nuevo dataframe que solo incluya a los países pertenecientes a la G20
G20 = pd.concat([arg,aust,bra,can,chin,fran,indi,indo,ita,jap,mex,kor,rus,safr,tur,ukin,usa,sarab,germ], axis=0)
#G20

#¿Cuáles son los 3 países que más contaminan en cada uno de los casos?
suma = G20.groupby('Country').sum()
#suma
pais_mas_contamina = {}
valoresgraf = ['Total', 'Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Per Capita']

for i in valoresgraf:
  pais_mas_contamina.update({i : suma.reset_index().nlargest(3, i)['Country'].tolist()})
print(f'Los 3 países que más contaminan en cada caso son: \n{pais_mas_contamina}\n')

#Considerando solo la emisión de los paises del G20, ¿Con qué porcentaje contribuye México al Total y Per Capita?
#Análisis por columna del total de México y la suma de todos los países del G20
colmexico = {}
for i in valoresgraf:
    totmexico = suma.loc['Mexico', i]
    totglobal = suma[i].sum()
    porcentage = totmexico / totglobal * 100
    colmexico.update({i : porcentage})
    print(f"De los países pertenecientes a la G20, México representa el {colmexico[i]:.2f}% del valor total de {i}")
# Out:
# Los 3 países que más contaminan en cada caso son:
# {'Total': ['USA', 'China', 'Russia'], 'Coal': ['China', 'USA', 'Germany'], 'Oil': ['USA', 'China', 'Russia'], 'Gas': ['USA', 'Russia', 'Canada'], 'Cement': ['China', 'USA', 'India'], 'Flaring': ['USA', 'Russia', 'Canada'], 'Per Capita': ['USA', 'United Kingdom', 'Germany']}
#
# De los países pertenecientes a la G20, México representa el 1.57% del valor total de Total
# De los países pertenecientes a la G20, México representa el 0.23% del valor total de Coal
# De los países pertenecientes a la G20, México representa el 3.28% del valor total de Oil
# De los países pertenecientes a la G20, México representa el 2.43% del valor total de Gas
# De los países pertenecientes a la G20, México representa el 2.11% del valor total de Cement
# De los países pertenecientes a la G20, México representa el 7.47% del valor total de Flaring
# De los países pertenecientes a la G20, México representa el 1.86% del valor total de Per Capita

# %% [markdown]
# ### Elimina NaNs

# %%
df.fillna(0)
# Out:
#            Country ISO 3166-1 alpha-3    Year         Total          Coal  \
# 0      Afghanistan                AFG  1750.0      0.000000      0.000000
# 1      Afghanistan                AFG  1751.0      0.000000      0.000000
# 2      Afghanistan                AFG  1752.0      0.000000      0.000000
# 3      Afghanistan                AFG  1753.0      0.000000      0.000000
# 4      Afghanistan                AFG  1754.0      0.000000      0.000000
# ...            ...                ...     ...           ...           ...
# 63099       Global                WLD  2017.0  36096.739276  14506.973805
# 63100       Global                WLD  2018.0  36826.506600  14746.830688
# 63101       Global                WLD  2019.0  37082.558969  14725.978025
# 63102       Global                WLD  2020.0  35264.085734  14174.564010
# 63103       Global                WLD  2021.0  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# ...
