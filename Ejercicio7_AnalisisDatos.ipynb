# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

#Este código fue realizado con la ayuda de un compañero de clase
imagen = Image.open('/content/WhatsApp Image 2023-02-26 at 6.07.37 PM.jpeg') 
im = imagen.convert('RGBA')
data = np.array(im)   # "data" is a height x width x 4 numpy array
red, green, blue, alpha = data.T 
Black_areas = (blue == 0) & (red == 0) & (green == 0)

data[..., :-1][Black_areas.T] = (255, 0, 0)

im2 = Image.fromarray(data)
im2
# Out:
# <PIL.Image.Image image mode=RGBA size=1411x1424 at 0x7F0BC673AE20>
